# %%
pip install networkx matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 9.9 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
# Arquivo de teste 'esparso-100.txt' criado automaticamente.
# ✔ Grafo exportado com sucesso para: F:\Users\Enzo HD\Github\Repos\er\minimum_path\Assigment\implementations\graphical\assets\topologia-esparsa-100.pdf
